# %%
# !pip install torchattacks
# !pip install pytorchcv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 208 kB 9.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 532 kB 6.9 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf ./code
# !cp -r /content/drive/MyDrive/LDH_workspace/Adversarial_Attack ./code
# Out:
# cp: cannot stat '/content/drive/MyDrive/LDH_workspace/Adversarial_Attack': No such file or directory

# %%
# !rm -rf /content/data/cifar10_selected /content/data/cifar10_anchor /content/data/cifar10_benign /content/data/adv_data

# %%
# !cp -r /content/data/cifar10_selected /content/drive/MyDrive/worksapce/data
# !cp -r /content/data/cifar10_anchor /content/drive/MyDrive/worksapce/data
# !cp -r /content/data/imagenet_selected /content/drive/MyDrive/worksapce/data
# !cp -r /content/data/imagenet_anchor /content/drive/MyDrive/worksapce/data
# Out:
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8191.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8192.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8193.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8194.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8195.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8196.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8197.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8198.pt': No space left on device
# cp: error writing '/content/drive/MyDrive/worksapce/data/imagenet_selected/8199.pt': No space left on device
# ...

# %%
# !cp -r /content/drive/MyDrive/worksapce/Adversarial_Attack ./code
# !cp -r /content/drive/MyDrive/worksapce/data ./data

# %%
! python3 ./code/adv.py
# Out:
# number of imagenet pretrained models with features: 3
# number of imagenet transfer models: 1
# imagenet num_images : 10000
# num_images : 100
# Accuracy of resnet101 : 100.0
# Accuracy of resnet152 : 100.0
# Accuracy of densenet121 : 100.0
# Attack mode is changed to 'targeted.'
#
# adv_epoch of MEMIFGSMmifgsm
# model: resnet101 untarget_success: 93.0
# model: resnet152 untarget_success: 94.0
# model: densenet121 untarget_success: 100.0
# tansfer model: resnet50 untarget_success: 67.0
# Attack mode is changed to 'targeted.'
#
# adv_epoch of APPROACHapproach
# model: resnet101 untarget_success: 81.0
# model: resnet152 untarget_success: 53.0
# model: densenet121 untarget_success: 86.0
# tansfer model: resnet50 untarget_success: 22.0

# %%
# %cd data/adv_data
# !rm *.pt
# !tar zcvf ../adv_data.tgz *
# %cd ../..
# Out:
# /content/data/adv_data
# APPROACHeps0/
# APPROACHeps0/truck/
# APPROACHeps0/truck/truck_8.jpg
# APPROACHeps0/truck/truck_3.jpg
# APPROACHeps0/truck/truck_7.jpg
# APPROACHeps0/truck/truck_9.jpg
# APPROACHeps0/truck/truck_4.jpg
# APPROACHeps0/truck/truck_2.jpg
# APPROACHeps0/truck/truck_5.jpg
# APPROACHeps0/truck/truck_1.jpg
# APPROACHeps0/truck/truck_6.jpg
# APPROACHeps0/truck/truck_12.jpg
# APPROACHeps0/truck/truck_10.jpg
# APPROACHeps0/truck/truck_11.jpg
# APPROACHeps0/cat/
# APPROACHeps0/cat/cat_3.jpg
# APPROACHeps0/cat/cat_7.jpg
# APPROACHeps0/cat/cat_4.jpg
# APPROACHeps0/cat/cat_8.jpg
# APPROACHeps0/cat/cat_2.jpg
# APPROACHeps0/cat/cat_5.jpg
# APPROACHeps0/cat/cat_6.jpg
# APPROACHeps0/cat/cat_9.jpg
# APPROACHeps0/cat/cat_1.jpg
# APPROACHeps0/ship/
# APPROACHeps0/ship/ship_3.jpg
# APPROACHeps0/ship/ship_7.jpg
# APPROACHeps0/ship/ship_2.jpg
# APPROACHeps0/ship/ship_4.jpg
# APPROACHeps0/ship/ship_9.jpg
# APPROACHeps0/ship/ship_1.jpg
# APPROACHeps0/ship/ship_5.jpg
# ...
